# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.11.1

# %%
#zbiór MNIST
mnist = tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()
#normalizacja danych
x_train, x_test = x_train/255.0, x_test/255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
#budowa model sieci neuronowej
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128,activation="relu"),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2964 - accuracy: 0.9137
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1441 - accuracy: 0.9570
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1094 - accuracy: 0.9670
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0877 - accuracy: 0.9732
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0763 - accuracy: 0.9763
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0668 - accuracy: 0.9784
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0600 - accuracy: 0.9809
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0525 - accuracy: 0.9828
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0478 - accuracy: 0.9845
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0455 - accuracy: 0.9851

# %%
#ocena modelu
test_loss,test_acc = model.evaluate(x_test,y_test)
print(f"strata: {test_loss}")
print(f"dokładność: {test_acc}")
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0726 - accuracy: 0.9791
# strata: 0.0725918859243393
# dokładność: 0.9790999889373779
